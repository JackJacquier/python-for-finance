# %% [markdown]
# # Exercise 1:
#
# ### The file ```AMZN_options.csv``` contains options data for amazon. For those of you not familiar with option data, an option is a financial derivatives that pays at expiration time $T$ and strike $K>0$:
#
# $$C(K,T)=(S_T-K)_+ \text{  if a call option}$$
# $$P(K,T)=(K-S_T)_+ \text{  if a put option}$$
#
# It is well known, that Put-Call parity implies the following relation:
#
# $$C(K,T)-P(K,T)=F(T)-K\cdot DF(T)$$
# where $F(T)$ is the forward price of the Stock and $DF(T)$ is the discount factor.
# ### a) Compute a new column labelled ```mid_price``` which corresponds to:
# $$\text{mid_price}=\frac{\text{bid}+\text{ask}}{2}$$
# ### b) For each available ```expiration_date``` perform a linear regression using the ```mid_price``` only for options ```whose trade_volume>25``` (note that both calls and puts need to satisfy this condition):
# $$C(K,T)-P(K,T)=a+b K$$ where $a$ corresponds to $F(T)$ and $b$ corresponds to $DF(T)$.
#
# ### you can use ```numpy.polyfit(x, y, deg=1)``` to fit a linear regression and obtain the coefficients
# ### c) Plot $F(T)$ and  $DF(T)$ as a function of $T$

# %%
import pandas as pd
pd.read_csv('AMZN_options.csv')
# Out:
#            contractSymbol        lastTradeDate  strike  lastPrice      bid  \
# 0     AMZN201106C01820000  2020-11-02 18:28:21  1820.0    1148.70  1139.35
# 1     AMZN201106C01830000  2020-11-02 18:28:21  1830.0    1146.25  1123.35
# 2     AMZN201106C01840000  2020-11-02 18:28:21  1840.0    1128.45  1116.55
# 3     AMZN201106C01850000  2020-11-02 18:28:21  1850.0    1126.00  1108.85
# 4     AMZN201106C01870000  2020-11-02 14:34:36  1870.0    1201.10  1086.10
# ...                   ...                  ...     ...        ...      ...
# 6032  AMZN230120P03600000  2020-10-28 16:43:01  3600.0     980.00  1061.70
# 6033  AMZN230120P03900000  2020-09-30 15:21:16  3900.0    1166.30  1227.55
# 6034  AMZN230120P04000000  2020-10-21 13:47:58  4000.0    1247.25  1359.95
# 6035  AMZN230120P04800000  2020-10-14 19:58:31  4800.0    1795.00  2017.40
# 6036  AMZN230120P05000000  2020-10-22 18:55:34  5000.0    2051.20  2193.50
#
#           ask    change  percentChange  volume  openInterest  \
# 0     1143.20 -62.51001      -5.160956    15.0           4.0
# 1     1127.75 -56.18994      -4.672994     1.0           2.0
# 2     1120.70 -62.75000      -5.267797     1.0           2.0
# 3     1112.60 -56.47998      -4.776401     1.0           3.0
# 4     1092.25 -17.23999      -1.415039     2.0           2.0
# ...       ...       ...            ...     ...           ...
# 6032  1078.45   0.00000       0.000000     1.0           2.0
# 6033  1245.00   0.00000       0.000000     1.0           0.0
# 6034  1376.50   0.00000       0.000000    55.0          59.0
# 6035  2033.00   0.00000       0.000000     5.0           4.0
# 6036  2203.00   0.00000       0.000000     1.0           1.0
#
#       impliedVolatility  inTheMoney contractSize currency expiration_date  \
# 0              0.000010        True      REGULAR      USD      2020-11-06
# 1              0.000010        True      REGULAR      USD      2020-11-06
# 2              0.000010        True      REGULAR      USD      2020-11-06
# 3              0.000010        True      REGULAR      USD      2020-11-06
# 4              0.000010        True      REGULAR      USD      2020-11-06
# ...                 ...         ...          ...      ...             ...
# 6032           0.375985        True      REGULAR      USD      2023-01-20
# 6033           0.340918        True      REGULAR      USD      2023-01-20
# 6034           0.371846        True      REGULAR      USD      2023-01-20
# 6035           0.363714        True      REGULAR      USD      2023-01-20
# 6036           0.358921        True      REGULAR      USD      2023-01-20
#
#      option_type
# 0              C
# 1              C
# 2              C
# 3              C
# 4              C
# ...          ...
# 6032           P
# 6033           P
# 6034           P
# 6035           P
# 6036           P
#
# [6037 rows x 16 columns]

# %%
Put_strikes=grouped_option_chain.loc["2020-10-16","P"].index
Call_strikes=grouped_option_chain.loc["2020-10-16","C"].index
intersect_strikes=np.intersect1d(Put_strikes,Call_strikes)

# %% [markdown]
# # Exercise 2:
#
# ### a) Using the forward prices $F(T)$ and Discount Factors $DF(T)$ obtained previously, calculate the implied volatility of each option using the  ```mid_price```. (Note that you will need to use the implied volatility calculation that you did in the Session 2 assignment)
#
# Recall that in the Black-Scholes model, the value of a European Call option on $(S_t)_{t\geq 0}$ is given at inception by,
#     $$C^{\mathrm{BS}}(S_0, K, T;\sigma) = F(T)\left(\mathcal{N}(d_{+}) - DF(T)K\mathcal{N}(d_{-})\right)$$
#     $$d_{\pm} = \frac{\log\left(\frac{F(T)}{K}\right)}{\sigma\sqrt{T}} \pm\frac{\sigma\sqrt{T}}{2}$$

# %% [markdown]
# ### Remark1 : Try to optimize your code to execute efficiently
# ### Remark2 : Note that some mid prices might lead to arbitrage and the solution for implied volatility might not exist
